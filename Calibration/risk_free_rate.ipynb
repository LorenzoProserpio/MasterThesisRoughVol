# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import risk_free_rates as rf

# %%
data =  pd.read_csv("risk_free_rates.csv")

tenor = np.array(data.Tenor)
rates = np.array(data.Rate)

# %%
# %matplotlib notebook

points = [0.6, 0.8, 1.25, 1.75, 5.25, 15.75, 21.3, 44.89]

plt.plot(tenor, rates)
plt.plot(points, rf.r(points), 'rx')
# Out:
# <img src="data:image/png;base64,..." width="888">
